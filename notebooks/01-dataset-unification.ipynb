# %%
# Cell 1: Install & Setup
# Amra 'fastparquet' use korbo karon eta disk space bachay ar fast kaj kore
# !pip install -q datasets pyarrow fastparquet
import pandas as pd
import os
import gc
import json
from datasets import load_dataset

# FINAL OUTPUT FOLDER (Sob data ekhane joma hobe)
OUTPUT_DIR = "swarabyanjan_final_dataset"
os.makedirs(OUTPUT_DIR, exist_ok=True)

print("🚀 Setup Complete. Output Folder Created: swarabyanjan_final_dataset")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.1 MB/s eta 0:00:00
# 🚀 Setup Complete. Output Folder Created: swarabyanjan_final_dataset

# %%
# Cell 2: Configuration & Mapping
# Kon dataset er kon column ke 'headline' ar 'body' banabo, tar list

CONFIG = {
    # 21GB Monster File
    'bangla-largest': {'headline': 'headline', 'body': 'body'},
    
    # Common CSVs
    'bdnews24': {'headline': 'title', 'body': 'contents'},
    'bdpratidin': {'headline': 'title', 'body': 'article'},
    'potrika': {'headline': 'Headline', 'body': 'News Article'},
    
    # Furcifer (data.json)
    'data': {'headline': 'title', 'body': 'content'},
    
    # Folder-based CSVs (Sports, Politics etc.)
    'Politics': {'headline': 'Heading', 'body': 'News'},
    'International': {'headline': 'Heading', 'body': 'News'},
    'Sports': {'headline': 'Heading', 'body': 'News'},
    'Science': {'headline': 'Heading', 'body': 'News'},
    'National': {'headline': 'Heading', 'body': 'News'},
    'Entertainment': {'headline': 'Heading', 'body': 'News'},
    'Education': {'headline': 'Heading', 'body': 'News'},
    'Economy': {'headline': 'Heading', 'body': 'News'},
    
    # 40k Dataset (Headless)
    'BalancedDataset': {'headline': None, 'body': 'article'}, 
    '40k': {'headline': None, 'body': 'article'}
}

print("✅ Configuration Loaded. Ready to standarize columns.")
# Out:
# ✅ Configuration Loaded. Ready to standarize columns.

# %%
# Cell 3: The Optimized Saver Function (CPU Safe)

def save_parquet(df, source_name, part_id):
    """ 
    1. Renames columns to 'headline' & 'body'
    2. Drops unnecessary columns (author, date, tags) to save space
    3. Saves as compressed Parquet file
    """
    # 1. Standardize Column Names
    rename_map = {}
    
    # Find mapping based on source name
    mapping = None
    for key in CONFIG:
        if key in source_name:
            mapping = CONFIG[key]
            break
    
    if not mapping:
        mapping = {'headline': 'title', 'body': 'content'} # Fallback default

    # Rename Headline
    if mapping['headline'] and mapping['headline'] in df.columns:
        rename_map[mapping['headline']] = 'headline'
    
    # Rename Body
    if mapping['body'] in df.columns:
        rename_map[mapping['body']] = 'body'
        
    df = df.rename(columns=rename_map)
    
    # Handle missing headline (e.g. for 40k dataset)
    if 'headline' not in df.columns:
        df['headline'] = '' 
        
    # CRITICAL: If body doesn't exist, skip this chunk
    if 'body' not in df.columns:
        return 

    # 2. Add Source & Select ONLY needed columns (Size Reduction Step)
    df['source'] = source_name
    try:
        df = df[['headline', 'body', 'source']].astype(str)
    except KeyError:
        return # Skip if columns missing
    
    # 3. Save Compressed
    safe_source = source_name.replace(" ", "_").replace("-", "_")
    filename = f"{OUTPUT_DIR}/{safe_source}_part_{part_id}.parquet"
    
    # 'snappy' compression is very fast and reduces size by 70-80%
    df.to_parquet(filename, index=False, compression='snappy')
    print(f"  ✅ Saved: {filename} ({len(df)} rows)")
    
    # Free RAM immediately
    del df; gc.collect()

# %%
# Cell 4: Process Local Files (Chunk by Chunk to prevent RAM Crash)
print("👉 Processing Local Kaggle Files...")

for root, dirs, files in os.walk('/kaggle/input'):
    folder_name = os.path.basename(root)
    
    for file in files:
        file_path = os.path.join(root, file)
        
        # Skip output files or checkpoints
        if file.endswith('.parquet') or 'checkpoint' in file: continue
        
        try:
            # A. HANDLE JSON FILES (Can be huge)
            if file.endswith('.json'):
                print(f"Reading JSON: {file} (Folder: {folder_name})...")
                try:
                    # Attempt to read standard JSON
                    df = pd.read_json(file_path)
                    save_parquet(df, folder_name, 0)
                except ValueError:
                    print(f"  ⚠️ JSON Error in {file} (Format or Size issue). Skipping.")
            
            # B. HANDLE CSV FILES (Read in Chunks)
            elif file.endswith('.csv'):
                print(f"Reading CSV: {file} (Folder: {folder_name})...")
                chunk_no = 0
                # 100k rows at a time = RAM Safe
                for chunk in pd.read_csv(file_path, chunksize=100000, on_bad_lines='skip'):
                    save_parquet(chunk, folder_name, chunk_no)
                    chunk_no += 1
            
            # C. HANDLE JSONL (Prothom Alo)
            elif file.endswith('.jsonl'):
                print(f"Reading JSONL: {file}...")
                data = []
                chunk_count = 0
                with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                    for i, line in enumerate(f):
                        try: 
                            obj = json.loads(line)
                            # Prothom Alo Specific Mapping
                            data.append({'headline': obj.get('Title'), 'body': obj.get('Body')})
                            
                            # Save every 200k lines
                            if len(data) >= 200000:
                                save_parquet(pd.DataFrame(data), 'prothomalo', chunk_count)
                                data = []
                                chunk_count += 1
                        except: continue
                # Save remaining
                if data:
                    save_parquet(pd.DataFrame(data), 'prothomalo', chunk_count)

        except Exception as e:
            print(f"  ❌ Error processing {file}: {e}")
            continue
# Out:
# 👉 Processing Local Kaggle Files...
# Reading JSONL: prothomalo_articles.jsonl...
#   ✅ Saved: swarabyanjan_final_dataset/prothomalo_part_0.parquet (200000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/prothomalo_part_1.parquet (6762 rows)
# Reading CSV: bdnews24.csv (Folder: bdnews24-corpus)...
#   ✅ Saved: swarabyanjan_final_dataset/bdnews24_corpus_part_0.parquet (100000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/bdnews24_corpus_part_1.parquet (100000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/bdnews24_corpus_part_2.parquet (100000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/bdnews24_corpus_part_3.parquet (100000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/bdnews24_corpus_part_4.parquet (17808 rows)
# Reading CSV: somoyer_alo_2020_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (646 rows)
# Reading CSV: ittefaq_2019_2020_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (29 rows)
# Reading CSV: jugantor_2016_2017_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (4429 rows)
# Reading CSV: jugantor_2018_2020_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (11304 rows)
# Reading CSV: Inqilab__2016_2020_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (468 rows)
# Reading CSV: kaler_kontho_2014_2020_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (1628 rows)
# Reading CSV: ittefaq_2015_2018_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (9220 rows)
# Reading CSV: jaijaidin_2019_2020_politics_text.csv (Folder: Politics)...
#   ✅ Saved: swarabyanjan_final_dataset/Politics_part_0.parquet (301 rows)
# Reading CSV: jaijaidin_2019_2020_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (545 rows)
# Reading CSV: somoyer_alo_2020_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (4026 rows)
# Reading CSV: jugantor_2018_2020_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (22056 rows)
# Reading CSV: ittefaq_2015_2018_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (24081 rows)
# Reading CSV: jugantor_2016_2017_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (8296 rows)
# Reading CSV: Inqilab__2016_2020_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (47026 rows)
# Reading CSV: kaler_kontho_2014_2020_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (8 rows)
# Reading CSV: ittefaq_2019_2020_worldnews_text.csv (Folder: International)...
#   ✅ Saved: swarabyanjan_final_dataset/International_part_0.parquet (8537 rows)
# Reading CSV: ittefaq_2015_2018_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (15244 rows)
# Reading CSV: jaijaidin_2019_2020_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (499 rows)
# Reading CSV: jugantor_2016_2017_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (21858 rows)
# Reading CSV: jugantor_2018_2020_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (16692 rows)
# Reading CSV: kaler_kontho_2014_2020_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (17618 rows)
# Reading CSV: Inqilab__2016_2020_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (26197 rows)
# Reading CSV: ittefaq_2019_2020_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (3440 rows)
# Reading CSV: somoyer_alo_2020_sports_text.csv (Folder: Sports)...
#   ✅ Saved: swarabyanjan_final_dataset/Sports_part_0.parquet (3492 rows)
# Reading CSV: jugantor_2018_2020_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (1821 rows)
# Reading CSV: ittefaq_2019_2020_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (357 rows)
# Reading CSV: ittefaq_2015_2018_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (4822 rows)
# Reading CSV: kaler_kontho_2014_2020_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (11476 rows)
# Reading CSV: jugantor_2016_2017_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (4172 rows)
# Reading CSV: Inqilab__2016_2020_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (544 rows)
# Reading CSV: somoyer_alo_2020_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (396 rows)
# Reading CSV: jaijaidin_2019_2020_scienceandtechnology_text.csv (Folder: Science_Technology)...
#   ✅ Saved: swarabyanjan_final_dataset/Science_Technology_part_0.parquet (53 rows)
# Reading CSV: jugantor_2016_2017_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (28217 rows)
# Reading CSV: kaler_kontho_2014_2020_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (18003 rows)
# Reading CSV: ittefaq_2019_2020_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (4936 rows)
# Reading CSV: somoyer_alo_2020_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (6365 rows)
# Reading CSV: jugantor_2018_2020_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (54105 rows)
# Reading CSV: ittefaq_2015_2018_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (75452 rows)
# Reading CSV: jaijaidin_2019_2020_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (4424 rows)
# Reading CSV: Inqilab__2016_2020_national_text.csv (Folder: National)...
#   ✅ Saved: swarabyanjan_final_dataset/National_part_0.parquet (100000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/National_part_1.parquet (3602 rows)
# Reading CSV: jugantor_2018_2020_entertainment_text.csv (Folder: Entertainment)...
#   ✅ Saved: swarabyanjan_final_dataset/Entertainment_part_0.parquet (4175 rows)
# Reading CSV: ittefaq_2019_2020_entertainment_text.csv (Folder: Entertainment)...
#   ✅ Saved: swarabyanjan_final_dataset/Entertainment_part_0.parquet (1773 rows)
# Reading CSV: somoyer_alo_2020_entertainment_text.csv (Folder: Entertainment)...
#   ✅ Saved: swarabyanjan_final_dataset/Entertainment_part_0.parquet (2906 rows)
# Reading CSV: jugantor_2016_2017_entertainment_text.csv (Folder: Entertainment)...
#   ✅ Saved: swarabyanjan_final_dataset/Entertainment_part_0.parquet (3959 rows)
# Reading CSV: ittefaq_2015_2018_entertainment_text.csv (Folder: Entertainment)...
#   ✅ Saved: swarabyanjan_final_dataset/Entertainment_part_0.parquet (9641 rows)
# Reading CSV: Inqilab__2016_2020_entertainment_text.csv (Folder: Entertainment)...
#   ✅ Saved: swarabyanjan_final_dataset/Entertainment_part_0.parquet (14898 rows)
# Reading CSV: jaijaidin_2019_2020_entertainment_text.csv (Folder: Entertainment)...
#   ✅ Saved: swarabyanjan_final_dataset/Entertainment_part_0.parquet (333 rows)
# Reading CSV: jaijaidin_2019_2020_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (171 rows)
# Reading CSV: ittefaq_2015_2018_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (3175 rows)
# Reading CSV: jugantor_2016_2017_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (1589 rows)
# Reading CSV: Inqilab__2016_2020_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (663 rows)
# Reading CSV: jugantor_2018_2020_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (3249 rows)
# Reading CSV: kaler_kontho_2014_2020_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (12704 rows)
# Reading CSV: somoyer_alo_2020_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (426 rows)
# Reading CSV: ittefaq_2019_2020_education_text.csv (Folder: Education)...
#   ✅ Saved: swarabyanjan_final_dataset/Education_part_0.parquet (50 rows)
# Reading CSV: jaijaidin_2019_2020_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (48 rows)
# Reading CSV: ittefaq_2019_2020_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (471 rows)
# Reading CSV: jugantor_2018_2020_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (930 rows)
# Reading CSV: Inqilab__2016_2020_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (11156 rows)
# Reading CSV: ittefaq_2015_2018_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (3247 rows)
# Reading CSV: jugantor_2016_2017_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (5154 rows)
# Reading CSV: kaler_kontho_2014_2020_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (15306 rows)
# Reading CSV: somoyer_alo_2020_economy_text.csv (Folder: Economy)...
#   ✅ Saved: swarabyanjan_final_dataset/Economy_part_0.parquet (2475 rows)
# Reading CSV: Sports_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (41000 rows)
# Reading CSV: ScienceTechnology_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (43395 rows)
# Reading CSV: Economy_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (40848 rows)
# Reading CSV: Entertainment_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (40772 rows)
# Reading CSV: politics_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (40179 rows)
# Reading CSV: Education_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (40916 rows)
# Reading CSV: International_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (41000 rows)
# Reading CSV: National_40k.csv (Folder: BalancedDataset)...
#   ✅ Saved: swarabyanjan_final_dataset/BalancedDataset_part_0.parquet (41000 rows)
# Reading JSON: data_v2.json (Folder: data_v2)...
#   ✅ Saved: swarabyanjan_final_dataset/data_v2_part_0.parquet (408471 rows)
# Reading JSON: data.json (Folder: data)...
#   ✅ Saved: swarabyanjan_final_dataset/data_part_0.parquet (437948 rows)
# Reading JSON: jug-part-1.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (238454 rows)
# Reading JSON: jug-part-0.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (238147 rows)
# Reading JSON: itte-part-4.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90155 rows)
# Reading JSON: jug-part-3.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (115406 rows)
# Reading JSON: pro-part-2.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: pro-part-6.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: itte-part-1.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (91716 rows)
# Reading JSON: itte-part-2.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (91754 rows)
# Reading JSON: pro-part-3.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: pro-part-0.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: itte-part-3.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (91877 rows)
# Reading JSON: pro-part-11.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (79471 rows)
# Reading JSON: pro-part-8.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: itte-part-0.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (143064 rows)
# Reading JSON: pro-part-9.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: pro-part-5.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: pro-part-10.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: pro-part-1.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: pro-part-4.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: pro-part-7.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (90000 rows)
# Reading JSON: jug-part-2.json (Folder: bangla-largest-newspaper-dataset)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_largest_newspaper_dataset_part_0.parquet (124666 rows)
# Reading CSV: 1000DaysNews.csv (Folder: bangla-news-datasets-from-bdpratidin)...
#   ✅ Saved: swarabyanjan_final_dataset/bangla_news_datasets_from_bdpratidin_part_0.parquet (100000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/bangla_news_datasets_from_bdpratidin_part_1.parquet (7642 rows)
# Reading CSV: 2018-02-01.csv (Folder: CSVs)...
# Reading CSV: 2019-06-11.csv (Folder: CSVs)...
# Reading CSV: 2019-11-09.csv (Folder: CSVs)...
# Reading CSV: 2020-07-10.csv (Folder: CSVs)...
# Reading CSV: 2018-12-27.csv (Folder: CSVs)...
# Reading CSV: 2018-03-02.csv (Folder: CSVs)...
# Reading CSV: 2018-05-31.csv (Folder: CSVs)...
# Reading CSV: 2018-12-10.csv (Folder: CSVs)...
# Reading CSV: 2018-11-06.csv (Folder: CSVs)...
# Reading CSV: 2019-07-02.csv (Folder: CSVs)...
# Reading CSV: 2018-01-12.csv (Folder: CSVs)...
# Reading CSV: 2019-06-09.csv (Folder: CSVs)...
# Reading CSV: 2020-08-19.csv (Folder: CSVs)...
# Reading CSV: 2019-09-24.csv (Folder: CSVs)...
# Reading CSV: 2018-04-19.csv (Folder: CSVs)...
# Reading CSV: 2020-04-19.csv (Folder: CSVs)...
# Reading CSV: 2018-05-27.csv (Folder: CSVs)...
# Reading CSV: 2019-06-01.csv (Folder: CSVs)...
# Reading CSV: 2018-05-02.csv (Folder: CSVs)...
#   ❌ Error processing 2018-05-02.csv: No columns to parse from file
# Reading CSV: 2019-03-23.csv (Folder: CSVs)...
# Reading CSV: 2018-10-30.csv (Folder: CSVs)...
# Reading CSV: 2018-08-12.csv (Folder: CSVs)...
# Reading CSV: 2020-06-13.csv (Folder: CSVs)...
# Reading CSV: 2018-06-16.csv (Folder: CSVs)...
#   ❌ Error processing 2018-06-16.csv: No columns to parse from file
# Reading CSV: 2020-01-05.csv (Folder: CSVs)...
# Reading CSV: 2018-07-20.csv (Folder: CSVs)...
# Reading CSV: 2019-05-11.csv (Folder: CSVs)...
# Reading CSV: 2019-05-01.csv (Folder: CSVs)...
# Reading CSV: 2019-02-09.csv (Folder: CSVs)...
# Reading CSV: 2020-02-23.csv (Folder: CSVs)...
# Reading CSV: 2018-03-14.csv (Folder: CSVs)...
# Reading CSV: 2018-04-14.csv (Folder: CSVs)...
# Reading CSV: 2018-01-11.csv (Folder: CSVs)...
# Reading CSV: 2018-04-05.csv (Folder: CSVs)...
# Reading CSV: 2019-09-05.csv (Folder: CSVs)...
# Reading CSV: 2019-02-14.csv (Folder: CSVs)...
# Reading CSV: 2019-05-26.csv (Folder: CSVs)...
# Reading CSV: 2020-02-08.csv (Folder: CSVs)...
# Reading CSV: 2018-05-29.csv (Folder: CSVs)...
# Reading CSV: 2019-09-04.csv (Folder: CSVs)...
# Reading CSV: 2020-01-04.csv (Folder: CSVs)...
# Reading CSV: 2019-05-04.csv (Folder: CSVs)...
# Reading CSV: 2020-07-11.csv (Folder: CSVs)...
# Reading CSV: 2018-04-15.csv (Folder: CSVs)...
#   ❌ Error processing 2018-04-15.csv: No columns to parse from file
# Reading CSV: 2018-08-17.csv (Folder: CSVs)...
# Reading CSV: 2018-10-23.csv (Folder: CSVs)...
# Reading CSV: 2020-09-04.csv (Folder: CSVs)...
# Reading CSV: 2019-04-26.csv (Folder: CSVs)...
# Reading CSV: 2019-09-10.csv (Folder: CSVs)...
# Reading CSV: 2019-01-31.csv (Folder: CSVs)...
# Reading CSV: 2018-01-29.csv (Folder: CSVs)...
# Reading CSV: 2019-09-21.csv (Folder: CSVs)...
# Reading CSV: 2020-03-02.csv (Folder: CSVs)...
# Reading CSV: 2019-05-02.csv (Folder: CSVs)...
#   ❌ Error processing 2019-05-02.csv: No columns to parse from file
# Reading CSV: 2018-05-16.csv (Folder: CSVs)...
# Reading CSV: 2019-05-22.csv (Folder: CSVs)...
# Reading CSV: 2018-05-14.csv (Folder: CSVs)...
# Reading CSV: 2020-02-29.csv (Folder: CSVs)...
# Reading CSV: 2019-04-19.csv (Folder: CSVs)...
# Reading CSV: 2018-02-08.csv (Folder: CSVs)...
# Reading CSV: 2018-10-11.csv (Folder: CSVs)...
# Reading CSV: 2019-04-08.csv (Folder: CSVs)...
# Reading CSV: 2019-01-10.csv (Folder: CSVs)...
# Reading CSV: 2020-07-28.csv (Folder: CSVs)...
# Reading CSV: 2018-11-09.csv (Folder: CSVs)...
# Reading CSV: 2018-02-02.csv (Folder: CSVs)...
# Reading CSV: 2018-10-01.csv (Folder: CSVs)...
# Reading CSV: 2020-05-08.csv (Folder: CSVs)...
# Reading CSV: 2020-08-14.csv (Folder: CSVs)...
# Reading CSV: 2019-10-07.csv (Folder: CSVs)...
# Reading CSV: 2018-12-05.csv (Folder: CSVs)...
# Reading CSV: 2018-07-07.csv (Folder: CSVs)...
# Reading CSV: 2019-08-12.csv (Folder: CSVs)...
#   ❌ Error processing 2019-08-12.csv: No columns to parse from file
# Reading CSV: 2019-07-07.csv (Folder: CSVs)...
# Reading CSV: 2019-07-17.csv (Folder: CSVs)...
# Reading CSV: 2019-06-03.csv (Folder: CSVs)...
# Reading CSV: 2020-08-07.csv (Folder: CSVs)...
# Reading CSV: 2019-04-09.csv (Folder: CSVs)...
# Reading CSV: 2019-01-28.csv (Folder: CSVs)...
# Reading CSV: 2018-08-31.csv (Folder: CSVs)...
# Reading CSV: 2019-05-15.csv (Folder: CSVs)...
# Reading CSV: 2020-01-25.csv (Folder: CSVs)...
# Reading CSV: 2019-03-11.csv (Folder: CSVs)...
# Reading CSV: 2018-06-27.csv (Folder: CSVs)...
# Reading CSV: 2019-01-20.csv (Folder: CSVs)...
# Reading CSV: 2018-05-24.csv (Folder: CSVs)...
# Reading CSV: 2020-08-22.csv (Folder: CSVs)...
# Reading CSV: 2019-11-07.csv (Folder: CSVs)...
# Reading CSV: 2019-09-12.csv (Folder: CSVs)...
# Reading CSV: 2018-04-08.csv (Folder: CSVs)...
# Reading CSV: 2018-06-06.csv (Folder: CSVs)...
# Reading CSV: 2018-04-29.csv (Folder: CSVs)...
# Reading CSV: 2018-05-17.csv (Folder: CSVs)...
# Reading CSV: 2018-12-01.csv (Folder: CSVs)...
# Reading CSV: 2019-10-30.csv (Folder: CSVs)...
# Reading CSV: 2019-08-02.csv (Folder: CSVs)...
# Reading CSV: 2019-10-26.csv (Folder: CSVs)...
# Reading CSV: 2018-01-21.csv (Folder: CSVs)...
# Reading CSV: 2018-02-18.csv (Folder: CSVs)...
# Reading CSV: 2018-03-26.csv (Folder: CSVs)...
# Reading CSV: 2018-01-24.csv (Folder: CSVs)...
# Reading CSV: 2020-06-15.csv (Folder: CSVs)...
# Reading CSV: 2020-02-22.csv (Folder: CSVs)...
# Reading CSV: 2018-11-22.csv (Folder: CSVs)...
#   ❌ Error processing 2018-11-22.csv: No columns to parse from file
# Reading CSV: 2019-10-05.csv (Folder: CSVs)...
# Reading CSV: 2018-04-11.csv (Folder: CSVs)...
# Reading CSV: 2020-07-08.csv (Folder: CSVs)...
# Reading CSV: 2018-09-08.csv (Folder: CSVs)...
# Reading CSV: 2018-10-14.csv (Folder: CSVs)...
# Reading CSV: 2020-01-19.csv (Folder: CSVs)...
# Reading CSV: 2018-09-25.csv (Folder: CSVs)...
# Reading CSV: 2018-09-17.csv (Folder: CSVs)...
# Reading CSV: 2020-08-16.csv (Folder: CSVs)...
# Reading CSV: 2018-09-15.csv (Folder: CSVs)...
# Reading CSV: 2018-06-23.csv (Folder: CSVs)...
# Reading CSV: 2018-06-28.csv (Folder: CSVs)...
# Reading CSV: 2020-08-03.csv (Folder: CSVs)...
#   ❌ Error processing 2020-08-03.csv: No columns to parse from file
# Reading CSV: 2020-02-18.csv (Folder: CSVs)...
# Reading CSV: 2018-10-24.csv (Folder: CSVs)...
# Reading CSV: 2020-08-30.csv (Folder: CSVs)...
# Reading CSV: 2019-11-25.csv (Folder: CSVs)...
# Reading CSV: 2020-01-30.csv (Folder: CSVs)...
# Reading CSV: 2019-12-14.csv (Folder: CSVs)...
# ...
# Reading CSV: 2018-10-15.csv (Folder: CSVs)...
# Reading CSV: 2017-12-29.csv (Folder: CSVs)...
# Reading CSV: 2018-11-14.csv (Folder: CSVs)...
# Reading CSV: 2018-03-01.csv (Folder: CSVs)...
# Reading CSV: 2020-03-03.csv (Folder: CSVs)...
# Reading CSV: 2018-01-18.csv (Folder: CSVs)...
# Reading CSV: 2019-09-28.csv (Folder: CSVs)...
# Reading CSV: 2019-08-18.csv (Folder: CSVs)...
# Reading CSV: 2020-06-27.csv (Folder: CSVs)...
# Reading CSV: 2020-09-03.csv (Folder: CSVs)...
# Reading CSV: 2018-01-04.csv (Folder: CSVs)...
# Reading CSV: 2019-03-04.csv (Folder: CSVs)...
# Reading CSV: 2019-08-22.csv (Folder: CSVs)...
# Reading CSV: 2020-02-02.csv (Folder: CSVs)...
# Reading CSV: 2020-03-17.csv (Folder: CSVs)...
# Reading CSV: 2019-08-19.csv (Folder: CSVs)...
# Reading CSV: 2019-03-17.csv (Folder: CSVs)...
# Reading CSV: 2019-07-18.csv (Folder: CSVs)...
# Reading CSV: 2018-10-09.csv (Folder: CSVs)...
# Reading CSV: 2018-10-13.csv (Folder: CSVs)...
# Reading CSV: 2018-09-16.csv (Folder: CSVs)...
# Reading CSV: 2019-03-14.csv (Folder: CSVs)...
# Reading CSV: 2020-02-14.csv (Folder: CSVs)...
# Reading CSV: 2020-02-10.csv (Folder: CSVs)...
# Reading CSV: 2018-05-30.csv (Folder: CSVs)...
# Reading CSV: 2020-06-29.csv (Folder: CSVs)...
# Reading CSV: 2019-01-27.csv (Folder: CSVs)...
# Reading CSV: 2019-01-03.csv (Folder: CSVs)...
# Reading CSV: 2018-03-29.csv (Folder: CSVs)...
# Reading CSV: 2019-08-14.csv (Folder: CSVs)...
#   ❌ Error processing 2019-08-14.csv: No columns to parse from file
# Reading CSV: 2019-02-19.csv (Folder: CSVs)...
# Reading CSV: 2019-03-19.csv (Folder: CSVs)...
# Reading CSV: 2018-01-19.csv (Folder: CSVs)...
# Reading CSV: 2018-05-22.csv (Folder: CSVs)...
# Reading CSV: 2019-06-27.csv (Folder: CSVs)...
# Reading CSV: 2020-05-23.csv (Folder: CSVs)...
# Reading CSV: 2019-10-11.csv (Folder: CSVs)...
# Reading CSV: 2020-06-09.csv (Folder: CSVs)...
# Reading CSV: 2017-12-28.csv (Folder: CSVs)...
# Reading CSV: 2018-02-11.csv (Folder: CSVs)...
# Reading CSV: 2018-07-10.csv (Folder: CSVs)...
# Reading CSV: 2018-01-16.csv (Folder: CSVs)...
# Reading CSV: 2019-07-20.csv (Folder: CSVs)...
# Reading CSV: 2018-09-03.csv (Folder: CSVs)...
# Reading CSV: 2018-03-06.csv (Folder: CSVs)...
# Reading CSV: 2018-12-30.csv (Folder: CSVs)...
# Reading CSV: 2020-04-12.csv (Folder: CSVs)...
# Reading CSV: 2020-06-08.csv (Folder: CSVs)...
# Reading CSV: 2019-07-24.csv (Folder: CSVs)...
# Reading CSV: 2018-09-09.csv (Folder: CSVs)...
# Reading CSV: 2018-02-10.csv (Folder: CSVs)...
# Reading CSV: 2019-04-29.csv (Folder: CSVs)...
# Reading CSV: 2018-05-06.csv (Folder: CSVs)...
# Reading CSV: 2018-08-07.csv (Folder: CSVs)...
# Reading CSV: 2020-05-17.csv (Folder: CSVs)...
# Reading CSV: 2018-07-18.csv (Folder: CSVs)...
# Reading CSV: 2018-07-27.csv (Folder: CSVs)...
# Reading CSV: 2018-01-15.csv (Folder: CSVs)...
# Reading CSV: 2020-04-23.csv (Folder: CSVs)...
# Reading CSV: 2017-12-24.csv (Folder: CSVs)...
# Reading CSV: 2018-05-28.csv (Folder: CSVs)...
# Reading CSV: 2019-08-17.csv (Folder: CSVs)...
# Reading CSV: 2019-06-25.csv (Folder: CSVs)...
# Reading CSV: 2020-08-27.csv (Folder: CSVs)...
# Reading CSV: 2019-02-01.csv (Folder: CSVs)...
# Reading CSV: 2019-04-15.csv (Folder: CSVs)...
#   ❌ Error processing 2019-04-15.csv: No columns to parse from file
# Reading CSV: 2018-11-29.csv (Folder: CSVs)...
# Reading CSV: 2018-11-08.csv (Folder: CSVs)...
# Reading CSV: 2018-01-03.csv (Folder: CSVs)...
# Reading CSV: 2019-07-06.csv (Folder: CSVs)...
# Reading CSV: 2019-12-30.csv (Folder: CSVs)...
# Reading CSV: 2020-03-07.csv (Folder: CSVs)...
# Reading CSV: 2020-07-27.csv (Folder: CSVs)...
# Reading CSV: 2019-08-29.csv (Folder: CSVs)...
# Reading CSV: 2018-11-23.csv (Folder: CSVs)...
# Reading CSV: 2019-08-13.csv (Folder: CSVs)...
#   ❌ Error processing 2019-08-13.csv: No columns to parse from file
# Reading CSV: 2018-04-18.csv (Folder: CSVs)...
# Reading CSV: 2019-04-12.csv (Folder: CSVs)...
# Reading CSV: 2020-06-02.csv (Folder: CSVs)...
# Reading CSV: 2019-01-09.csv (Folder: CSVs)...
# Reading CSV: 2018-12-20.csv (Folder: CSVs)...
# Reading CSV: 2018-01-25.csv (Folder: CSVs)...
# Reading CSV: 2018-01-09.csv (Folder: CSVs)...
# Reading CSV: 2018-12-28.csv (Folder: CSVs)...
# Reading CSV: 2018-10-06.csv (Folder: CSVs)...
# Reading CSV: 2018-04-30.csv (Folder: CSVs)...
# Reading CSV: 2020-02-19.csv (Folder: CSVs)...
# Reading CSV: 2017-12-16.csv (Folder: CSVs)...
# Reading CSV: 2018-09-22.csv (Folder: CSVs)...
#   ❌ Error processing 2018-09-22.csv: No columns to parse from file
# Reading CSV: 2019-07-14.csv (Folder: CSVs)...
# Reading CSV: 2019-10-31.csv (Folder: CSVs)...
# Reading CSV: 2018-04-09.csv (Folder: CSVs)...
# Reading CSV: 2019-05-19.csv (Folder: CSVs)...
# Reading CSV: 2018-08-13.csv (Folder: CSVs)...
# Reading CSV: 2020-04-11.csv (Folder: CSVs)...
# Reading CSV: 2019-02-12.csv (Folder: CSVs)...
# Reading CSV: 2018-08-28.csv (Folder: CSVs)...
# Reading CSV: 2018-02-03.csv (Folder: CSVs)...
# Reading CSV: 2018-08-20.csv (Folder: CSVs)...
# Reading CSV: 2019-10-25.csv (Folder: CSVs)...
# Reading CSV: 2020-01-26.csv (Folder: CSVs)...
# Reading CSV: 2019-11-11.csv (Folder: CSVs)...
#   ❌ Error processing 2019-11-11.csv: No columns to parse from file
# Reading CSV: 2018-07-16.csv (Folder: CSVs)...
# Reading CSV: 2019-11-15.csv (Folder: CSVs)...
# Reading CSV: 2020-01-18.csv (Folder: CSVs)...
# Reading CSV: 2019-05-25.csv (Folder: CSVs)...
# Reading CSV: 2019-06-13.csv (Folder: CSVs)...
# Reading CSV: 2019-08-28.csv (Folder: CSVs)...
# Reading CSV: 2018-04-28.csv (Folder: CSVs)...
# Reading CSV: 2019-02-15.csv (Folder: CSVs)...
# Reading CSV: 2019-04-24.csv (Folder: CSVs)...
# Reading CSV: 2018-02-06.csv (Folder: CSVs)...
# Reading CSV: 2019-11-02.csv (Folder: CSVs)...
# Reading CSV: 2020-05-26.csv (Folder: CSVs)...
#   ❌ Error processing 2020-05-26.csv: No columns to parse from file
# Reading CSV: 2018-06-02.csv (Folder: CSVs)...
# Reading CSV: 2020-09-02.csv (Folder: CSVs)...
# Reading CSV: 2020-07-07.csv (Folder: CSVs)...
# Reading CSV: 2018-03-23.csv (Folder: CSVs)...
# Reading CSV: 2019-06-20.csv (Folder: CSVs)...
# Reading CSV: 2018-12-12.csv (Folder: CSVs)...
# Reading CSV: 2019-12-18.csv (Folder: CSVs)...
# Reading CSV: 2018-09-19.csv (Folder: CSVs)...
# Reading CSV: 2018-03-03.csv (Folder: CSVs)...
# Reading CSV: 2020-02-21.csv (Folder: CSVs)...
# Reading CSV: 2020-05-02.csv (Folder: CSVs)...
#   ❌ Error processing 2020-05-02.csv: No columns to parse from file
# Reading CSV: 2020-01-24.csv (Folder: CSVs)...
# Reading CSV: 2019-09-09.csv (Folder: CSVs)...
# Reading CSV: 2019-07-08.csv (Folder: CSVs)...
# Reading CSV: 2019-08-08.csv (Folder: CSVs)...
# Reading CSV: 2019-06-30.csv (Folder: CSVs)...
# Reading CSV: 2018-11-11.csv (Folder: CSVs)...
# Reading CSV: 2020-08-25.csv (Folder: CSVs)...
# Reading CSV: 2019-02-08.csv (Folder: CSVs)...
# Reading CSV: 2020-08-17.csv (Folder: CSVs)...
# Reading CSV: 2018-02-05.csv (Folder: CSVs)...
# Reading CSV: 2019-07-30.csv (Folder: CSVs)...
# Reading CSV: 2018-04-20.csv (Folder: CSVs)...
# Reading CSV: 2020-02-24.csv (Folder: CSVs)...
# Reading CSV: 2019-05-30.csv (Folder: CSVs)...
# Reading CSV: 2018-12-31.csv (Folder: CSVs)...
# Reading CSV: 2019-10-17.csv (Folder: CSVs)...
# Reading CSV: 2018-05-21.csv (Folder: CSVs)...
# Reading CSV: 2018-06-18.csv (Folder: CSVs)...
#   ❌ Error processing 2018-06-18.csv: No columns to parse from file
# Reading CSV: 2019-10-16.csv (Folder: CSVs)...
# Reading CSV: 2019-02-07.csv (Folder: CSVs)...
# Reading CSV: 2020-08-06.csv (Folder: CSVs)...
# Reading CSV: 2018-12-22.csv (Folder: CSVs)...
# Reading CSV: 2020-03-12.csv (Folder: CSVs)...
# Reading CSV: 2018-04-13.csv (Folder: CSVs)...
# Reading CSV: 2019-05-09.csv (Folder: CSVs)...
# Reading CSV: 2019-06-21.csv (Folder: CSVs)...
# Reading CSV: 2019-04-27.csv (Folder: CSVs)...
# Reading CSV: 2019-05-10.csv (Folder: CSVs)...
# Reading CSV: 2019-02-22.csv (Folder: CSVs)...
# Reading CSV: 2018-10-19.csv (Folder: CSVs)...
# Reading CSV: 2018-03-13.csv (Folder: CSVs)...
# Reading CSV: 2020-02-17.csv (Folder: CSVs)...
# Reading CSV: 2018-07-24.csv (Folder: CSVs)...
# Reading CSV: 2019-08-30.csv (Folder: CSVs)...
# Reading CSV: 2020-03-22.csv (Folder: CSVs)...
# Reading CSV: 2020-05-18.csv (Folder: CSVs)...
# Reading CSV: 2019-07-26.csv (Folder: CSVs)...
# Reading CSV: 2018-07-23.csv (Folder: CSVs)...
# Reading CSV: 2019-01-07.csv (Folder: CSVs)...
# Reading CSV: 2019-01-23.csv (Folder: CSVs)...
# Reading CSV: 2019-08-05.csv (Folder: CSVs)...
# Reading CSV: 2020-07-12.csv (Folder: CSVs)...
# Reading CSV: 2018-12-09.csv (Folder: CSVs)...
# Reading CSV: 2019-04-22.csv (Folder: CSVs)...
#   ❌ Error processing 2019-04-22.csv: No columns to parse from file
# Reading CSV: 2018-07-22.csv (Folder: CSVs)...
# Reading CSV: 2020-05-06.csv (Folder: CSVs)...
# Reading CSV: 2018-01-08.csv (Folder: CSVs)...
# Reading CSV: 2020-08-09.csv (Folder: CSVs)...
# Reading CSV: 2017-12-27.csv (Folder: CSVs)...
# Reading CSV: 2018-08-10.csv (Folder: CSVs)...
# Reading CSV: 2019-08-01.csv (Folder: CSVs)...
# Reading CSV: 2018-04-21.csv (Folder: CSVs)...
# Reading CSV: 2018-12-02.csv (Folder: CSVs)...
# Reading CSV: 2019-11-03.csv (Folder: CSVs)...
# Reading CSV: 2018-10-16.csv (Folder: CSVs)...
# Reading CSV: 2019-09-15.csv (Folder: CSVs)...
# Reading CSV: 2020-07-31.csv (Folder: CSVs)...
# Reading CSV: 2019-01-02.csv (Folder: CSVs)...
# Reading CSV: 2019-08-31.csv (Folder: CSVs)...
# Reading CSV: 2018-08-30.csv (Folder: CSVs)...
# Reading CSV: 2020-05-14.csv (Folder: CSVs)...
# Reading CSV: 2020-05-05.csv (Folder: CSVs)...
# Reading CSV: 2020-05-03.csv (Folder: CSVs)...
# Reading CSV: 2019-02-06.csv (Folder: CSVs)...
# Reading CSV: 2020-01-29.csv (Folder: CSVs)...
# Reading CSV: 2020-04-17.csv (Folder: CSVs)...
# Reading CSV: 2019-11-22.csv (Folder: CSVs)...
# Reading CSV: 2019-12-03.csv (Folder: CSVs)...
# Reading CSV: 2018-11-01.csv (Folder: CSVs)...
# Reading CSV: 2019-03-01.csv (Folder: CSVs)...
# Reading CSV: 2019-09-22.csv (Folder: CSVs)...
# Reading CSV: 2020-05-16.csv (Folder: CSVs)...
# Reading CSV: 2020-04-29.csv (Folder: CSVs)...
# Reading CSV: 2019-06-05.csv (Folder: CSVs)...
#   ❌ Error processing 2019-06-05.csv: No columns to parse from file
# Reading CSV: 2018-05-11.csv (Folder: CSVs)...
# Reading CSV: 2018-03-09.csv (Folder: CSVs)...
# Reading CSV: 2019-04-21.csv (Folder: CSVs)...
# Reading CSV: 2020-08-12.csv (Folder: CSVs)...
# Reading CSV: 2019-11-01.csv (Folder: CSVs)...
# Reading CSV: 2018-03-28.csv (Folder: CSVs)...
# Reading CSV: 2018-08-23.csv (Folder: CSVs)...
#   ❌ Error processing 2018-08-23.csv: No columns to parse from file
# Reading CSV: 2018-02-24.csv (Folder: CSVs)...
# Reading CSV: 2018-11-28.csv (Folder: CSVs)...
# Reading CSV: 2019-04-28.csv (Folder: CSVs)...
# Reading CSV: 2020-05-13.csv (Folder: CSVs)...
# Reading CSV: 2018-06-30.csv (Folder: CSVs)...
# Reading CSV: 2019-10-21.csv (Folder: CSVs)...
# Reading CSV: 2018-09-28.csv (Folder: CSVs)...
# Reading CSV: 2018-06-21.csv (Folder: CSVs)...
# Reading CSV: 2018-03-11.csv (Folder: CSVs)...
# Reading CSV: 2020-01-07.csv (Folder: CSVs)...
# Reading CSV: 2018-10-26.csv (Folder: CSVs)...
# Reading CSV: 2018-01-30.csv (Folder: CSVs)...
# Reading CSV: 2019-07-23.csv (Folder: CSVs)...
# Reading CSV: 2018-09-11.csv (Folder: CSVs)...
# Reading CSV: 2018-08-22.csv (Folder: CSVs)...
#   ❌ Error processing 2018-08-22.csv: No columns to parse from file
# Reading CSV: 2018-06-24.csv (Folder: CSVs)...
# Reading CSV: 2018-10-17.csv (Folder: CSVs)...
# Reading CSV: 2019-01-29.csv (Folder: CSVs)...
# Reading CSV: 2019-10-08.csv (Folder: CSVs)...
# Reading CSV: 2020-05-04.csv (Folder: CSVs)...
# Reading CSV: 2018-06-29.csv (Folder: CSVs)...

# %%
# Cell 5: Process Hugging Face (Zabir Nabil)
print("\n👉 Downloading & Processing Hugging Face (zabir-nabil/bangla_newspaper_dataset)...")

try:
    # Stream mode use korchi jate purota ekbare download na hoy
    ds = load_dataset("zabir-nabil/bangla_newspaper_dataset", split="train")
    
    # Convert to Pandas in Batches (RAM Safe)
    batch_size = 200000
    total_rows = len(ds)
    
    for i in range(0, total_rows, batch_size):
        # Get a slice
        df_batch = ds.select(range(i, min(i + batch_size, total_rows))).to_pandas()
        
        # Manual Mapping for HF
        df_batch = df_batch.rename(columns={'title': 'headline', 'content': 'body'})
        
        # Save
        save_parquet(df_batch, 'hf_zabir_nabil', i // batch_size)
        
        del df_batch; gc.collect()
        
    print("✅ Hugging Face Data Processed Successfully!")

except Exception as e:
    print(f"  ❌ HF Error: {e}")

print(f"\n🎉 ALL DONE! All files are optimized and merged in '{OUTPUT_DIR}'")
# Out:
# 👉 Downloading & Processing Hugging Face (zabir-nabil/bangla_newspaper_dataset)...
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00003.parquet:   0%|          | 0.00/170M [00:00<?, ?B/s]
# data/train-00001-of-00003.parquet:   0%|          | 0.00/170M [00:00<?, ?B/s]
# data/train-00002-of-00003.parquet:   0%|          | 0.00/171M [00:00<?, ?B/s]
# data/valid-00000-of-00001.parquet:   0%|          | 0.00/118M [00:00<?, ?B/s]
# data/test_1-00000-of-00001.parquet:   0%|          | 0.00/157M [00:00<?, ?B/s]
# data/test_2-00000-of-00001.parquet:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/265506 [00:00<?, ? examples/s]
# Generating valid split:   0%|          | 0/61274 [00:00<?, ? examples/s]
# Generating test_1 split:   0%|          | 0/81691 [00:00<?, ? examples/s]
# Generating test_2 split:   0%|          | 0/495 [00:00<?, ? examples/s]
#   ✅ Saved: swarabyanjan_final_dataset/hf_zabir_nabil_part_0.parquet (200000 rows)
#   ✅ Saved: swarabyanjan_final_dataset/hf_zabir_nabil_part_1.parquet (65506 rows)
# ✅ Hugging Face Data Processed Successfully!
#
# 🎉 ALL DONE! All files are optimized and merged in 'swarabyanjan_final_dataset'
